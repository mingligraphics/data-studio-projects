# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams['pdf.fonttype'] = 42

# %%
df = pd.read_csv("2020_elected_officials.csv")

# %%
df = df[:863]

# %%
df['Level'].value_counts(dropna=False)
# Out:
# Local        523
# State        257
# Level         29
# Statewide     26
# Federal       20
# NaN            8
# Name: Level, dtype: int64

# %%
df = df[df.Level != 'Level']

# %%
df['Level'] = df['Level'].str.replace("Statewide","State")

# %%
df.Level.value_counts(dropna=False)
# Out:
# Local      523
# State      283
# Federal     20
# NaN          8
# Name: Level, dtype: int64

# %%
df.at[781, 'Level'] = 'Local'

# %%
df.at[784, 'Level'] = 'Local'

# %%
df.at[786, 'Level'] = 'Local'

# %%
df.at[801, 'Level'] = 'Local'

# %%
df.at[803, 'Level'] = 'Local'

# %%
df.at[805, 'Level'] = 'Local'

# %%
df.at[809, 'Level'] = 'Local'

# %%
df.drop(818, inplace=True)

# %%
df.Level.value_counts()
# Out:
# Local      530
# State      283
# Federal     20
# Name: Level, dtype: int64

# %%
df.Level.value_counts().plot(kind='barh')

# %%
df[df.Level == 'Federal']
# Out:
#        #                      Name State    Level    Body Type
# 2      3  Amata Coleman Radewag...    AS  Federal   U.S. House
# 9     10                  Ami Bera    CA  Federal   U.S. House
# 10    11                  Judy Chu    CA  Federal   U.S. House
# 11    12                    TJ Cox    CA  Federal   U.S. House
# 12    13             Kamala Harris    CA  Federal  U.S. Senate
# 13    14                 Ro Khanna    CA  Federal   U.S. House
# 14    15                  Ted Lieu    CA  Federal   U.S. House
# 15    16              Doris Matsui    CA  Federal   U.S. House
# 16    17               Mark Takano    CA  Federal   U.S. House
# 297  288          Stephanie Murphy    FL  Federal   U.S. House
# 303  294       Michael San Nicolas    GU  Federal   U.S. House
# 305  296             Tulsi Gabbard    HI  Federal   U.S. House
# 306  297              Mazie Hirono    HI  Federal  U.S. Senate
# 385  373           Tammy Duckworth    IL  Federal  U.S. Senate
# 386  374       Raja Krishnamoorthi    IL  Federal   U.S. House
# 429  416           Gregorio Sablan    MP  Federal   U.S. House
# 438  424                  Andy Kim    NJ  Federal   U.S. House
# 457  443                Grace Meng    NY  Federal   U.S. House
# 506  490               Bobby Scott    VA  Federal   U.S. House
# 511  495           Pramila Jayapal    WA  Federal   U.S. House

# %%
df_pop = pd.read_csv("state_population.csv", names=['state','population'])

# %%
df_pop
# Out:
#                    state  population
# 0             California    39747267
# 1                  Texas    29087070
# 2                Florida    21646155
# 3               New York    19491339
# 4           Pennsylvania    12813969
# 5               Illinois    12700381
# 6                   Ohio    11718568
# 7                Georgia    10627767
# 8         North Carolina    10497741
# 9               Michigan    10020472
# 10            New Jersey     8922547
# 11              Virginia     8571946
# 12            Washington     7666343
# 13               Arizona     7275070
# 14         Massachusetts     6939373
# 15             Tennessee     6833793
# 16               Indiana     6718616
# 17              Missouri     6147861
# 18              Maryland     6062917
# 19             Wisconsin     5832661
# 20              Colorado     5770545
# 21             Minnesota     5655925
# 22        South Carolina     5147111
# 23               Alabama     4898246
# 24             Louisiana     4652581
# 25              Kentucky     4484047
# 26                Oregon     4245901
# 27              Oklahoma     3948950
# 28           Connecticut     3567871
# 29                  Utah     3221610
# 30                  Iowa     3167997
# 31           Puerto Rico     3113659
# 32                Nevada     3087025
# 33              Arkansas     3026412
# 34           Mississippi     2987895
# 35                Kansas     2910931
# 36            New Mexico     2096034
# 37              Nebraska     1940919
# 38         West Virginia     1791951
# 39                 Idaho     1790182
# 40                Hawaii     1416589
# 41         New Hampshire     1363852
# 42                 Maine     1342097
# 43               Montana     1074532
# 44          Rhode Island     1056738
# 45              Delaware      975033
# 46          South Dakota      892631
# 47          North Dakota      760900
# 48                Alaska      735720
# 49  District of Columbia      711571
# 50               Vermont      627180
# 51               Wyoming      572381

# %%
df_state = pd.read_csv("state_name.csv",names=['STATE','State','ID','Abr'])

# %%
df_pop = pd.merge(df_state, df_pop, left_on='State',right_on='state')

# %%
df_pop
# Out:
#              STATE           State  ID     Abr           state  population
# 0          ALABAMA         Alabama  AL    Ala.         Alabama     4898246
# 1           ALASKA          Alaska  AK  Alaska          Alaska      735720
# 2          ARIZONA         Arizona  AZ   Ariz.         Arizona     7275070
# 3         ARKANSAS        Arkansas  AR    Ark.        Arkansas     3026412
# 4       CALIFORNIA      California  CA  Calif.      California    39747267
# 5         COLORADO        Colorado  CO   Colo.        Colorado     5770545
# 6      CONNECTICUT     Connecticut  CT   Conn.     Connecticut     3567871
# 7         DELAWARE        Delaware  DE    Del.        Delaware      975033
# 8          FLORIDA         Florida  FL    Fla.         Florida    21646155
# 9          GEORGIA         Georgia  GA     Ga.         Georgia    10627767
# 10          HAWAII          Hawaii  HI  Hawaii          Hawaii     1416589
# 11           IDAHO           Idaho  ID   Idaho           Idaho     1790182
# 12        ILLINOIS        Illinois  IL    Ill.        Illinois    12700381
# 13         INDIANA         Indiana  IN    Ind.         Indiana     6718616
# 14            IOWA            Iowa  IA    Iowa            Iowa     3167997
# 15          KANSAS          Kansas  KS    Kan.          Kansas     2910931
# 16        KENTUCKY        Kentucky  KY     Ky.        Kentucky     4484047
# 17       LOUISIANA       Louisiana  LA     La.       Louisiana     4652581
# 18           MAINE           Maine  ME   Maine           Maine     1342097
# 19        MARYLAND        Maryland  MD     Md.        Maryland     6062917
# 20   MASSACHUSETTS   Massachusetts  MA   Mass.   Massachusetts     6939373
# 21        MICHIGAN        Michigan  MI   Mich.        Michigan    10020472
# 22       MINNESOTA       Minnesota  MN   Minn.       Minnesota     5655925
# 23     MISSISSIPPI     Mississippi  MS   Miss.     Mississippi     2987895
# 24        MISSOURI        Missouri  MO     Mo.        Missouri     6147861
# 25         MONTANA         Montana  MT   Mont.         Montana     1074532
# 26        NEBRASKA        Nebraska  NE    Neb.        Nebraska     1940919
# 27          NEVADA          Nevada  NV    Nev.          Nevada     3087025
# 28   NEW HAMPSHIRE   New Hampshire  NH    N.H.   New Hampshire     1363852
# 29      NEW JERSEY      New Jersey  NJ    N.J.      New Jersey     8922547
# 30      NEW MEXICO      New Mexico  NM    N.M.      New Mexico     2096034
# 31        NEW YORK        New York  NY    N.Y.        New York    19491339
# 32  NORTH CAROLINA  North Carolina  NC    N.C.  North Carolina    10497741
# 33    NORTH DAKOTA    North Dakota  ND    N.D.    North Dakota      760900
# 34            OHIO            Ohio  OH    Ohio            Ohio    11718568
# 35        OKLAHOMA        Oklahoma  OK   Okla.        Oklahoma     3948950
# 36          OREGON          Oregon  OR    Ore.          Oregon     4245901
# 37    PENNSYLVANIA    Pennsylvania  PA     Pa.    Pennsylvania    12813969
# 38    RHODE ISLAND    Rhode Island  RI    R.I.    Rhode Island     1056738
# 39  SOUTH CAROLINA  South Carolina  SC    S.C.  South Carolina     5147111
# 40    SOUTH DAKOTA    South Dakota  SD    S.D.    South Dakota      892631
# 41       TENNESSEE       Tennessee  TN   Tenn.       Tennessee     6833793
# 42           TEXAS           Texas  TX   Texas           Texas    29087070
# 43            UTAH            Utah  UT    Utah            Utah     3221610
# 44         VERMONT         Vermont  VT     Vt.         Vermont      627180
# 45        VIRGINIA        Virginia  VA     Va.        Virginia     8571946
# 46      WASHINGTON      Washington  WA   Wash.      Washington     7666343
# 47   WEST VIRGINIA   West Virginia  WV   W.Va.   West Virginia     1791951
# 48       WISCONSIN       Wisconsin  WI    Wis.       Wisconsin     5832661
# 49         WYOMING         Wyoming  WY    Wyo.         Wyoming      572381

# %%
df_officials = pd.DataFrame(df['State'].value_counts()).reset_index()

# %%
merge = pd.merge(df_pop, df_officials, left_on='ID', right_on='index')

# %%
merge['ratio'] = 1000000 * merge['State_y'] / merge['population']

# %%
merge
# Out:
#              STATE         State_x  ID     Abr           state  population  \
# 0           ALASKA          Alaska  AK  Alaska          Alaska      735720
# 1          ARIZONA         Arizona  AZ   Ariz.         Arizona     7275070
# 2       CALIFORNIA      California  CA  Calif.      California    39747267
# 3      CONNECTICUT     Connecticut  CT   Conn.     Connecticut     3567871
# 4          FLORIDA         Florida  FL    Fla.         Florida    21646155
# 5          GEORGIA         Georgia  GA     Ga.         Georgia    10627767
# 6           HAWAII          Hawaii  HI  Hawaii          Hawaii     1416589
# 7            IDAHO           Idaho  ID   Idaho           Idaho     1790182
# 8         ILLINOIS        Illinois  IL    Ill.        Illinois    12700381
# 9          INDIANA         Indiana  IN    Ind.         Indiana     6718616
# 10          KANSAS          Kansas  KS    Kan.          Kansas     2910931
# 11        KENTUCKY        Kentucky  KY     Ky.        Kentucky     4484047
# 12       LOUISIANA       Louisiana  LA     La.       Louisiana     4652581
# 13           MAINE           Maine  ME   Maine           Maine     1342097
# 14        MARYLAND        Maryland  MD     Md.        Maryland     6062917
# 15   MASSACHUSETTS   Massachusetts  MA   Mass.   Massachusetts     6939373
# 16        MICHIGAN        Michigan  MI   Mich.        Michigan    10020472
# 17       MINNESOTA       Minnesota  MN   Minn.       Minnesota     5655925
# 18        MISSOURI        Missouri  MO     Mo.        Missouri     6147861
# 19          NEVADA          Nevada  NV    Nev.          Nevada     3087025
# 20   NEW HAMPSHIRE   New Hampshire  NH    N.H.   New Hampshire     1363852
# 21      NEW JERSEY      New Jersey  NJ    N.J.      New Jersey     8922547
# 22      NEW MEXICO      New Mexico  NM    N.M.      New Mexico     2096034
# 23        NEW YORK        New York  NY    N.Y.        New York    19491339
# 24  NORTH CAROLINA  North Carolina  NC    N.C.  North Carolina    10497741
# 25            OHIO            Ohio  OH    Ohio            Ohio    11718568
# 26        OKLAHOMA        Oklahoma  OK   Okla.        Oklahoma     3948950
# 27          OREGON          Oregon  OR    Ore.          Oregon     4245901
# 28    PENNSYLVANIA    Pennsylvania  PA     Pa.    Pennsylvania    12813969
# 29    RHODE ISLAND    Rhode Island  RI    R.I.    Rhode Island     1056738
# 30  SOUTH CAROLINA  South Carolina  SC    S.C.  South Carolina     5147111
# 31       TENNESSEE       Tennessee  TN   Tenn.       Tennessee     6833793
# 32           TEXAS           Texas  TX   Texas           Texas    29087070
# 33            UTAH            Utah  UT    Utah            Utah     3221610
# 34        VIRGINIA        Virginia  VA     Va.        Virginia     8571946
# 35      WASHINGTON      Washington  WA   Wash.      Washington     7666343
# 36       WISCONSIN       Wisconsin  WI    Wis.       Wisconsin     5832661
# 37         WYOMING         Wyoming  WY    Wyo.         Wyoming      572381
#
#    index  State_y      ratio
# 0     AK        5   6.796064
# 1     AZ       11   1.512013
# 2     CA      358   9.006909
# 3     CT        3   0.840838
# 4     FL        5   0.230988
# 5     GA        5   0.470466
# 6     HI      105  74.121711
# 7     ID        3   1.675807
# 8     IL        6   0.472427
# 9     IN        4   0.595361
# 10    KS        1   0.343533
# 11    KY        1   0.223013
# 12    LA        2   0.429869
# 13    ME        1   0.745103
# 14    MD       14   2.309120
# 15    MA       11   1.585158
# 16    MI        7   0.698570
# 17    MN       13   2.298475
# 18    MO        1   0.162658
# 19    NV        4   1.295746
# 20    NH        3   2.199652
# 21    NJ       52   5.827932
# 22    NM        1   0.477091
# 23    NY       21   1.077402
# 24    NC        6   0.571552
# 25    OH        4   0.341339
# 26    OK        2   0.506464
# 27    OR        6   1.413128
# 28    PA        4   0.312159
# 29    RI        1   0.946308
# 30    SC        1   0.194284
# 31    TN        4   0.585326
# 32    TX       14   0.481314
# 33    UT        5   1.552019
# 34    VA        9   1.049937
# 35    WA       35   4.565410
# 36    WI       10   1.714483
# 37    WY        1   1.747088

# %%
df_officials
# Out:
#    index  State
# 0     CA    358
# 1     HI    105
# 2     NJ     52
# 3     AS     42
# 4     WA     35
# 5     MP     32
# 6     NY     21
# 7     GU     19
# 8     MD     14
# 9     TX     14
# 10    MN     13
# 11    MA     11
# 12    AZ     11
# 13    WI     10
# 14    VA      9
# 15    MI      7
# 16    IL      6
# 17    NC      6
# 18    OR      6
# 19    UT      5
# 20    FL      5
# 21    GA      5
# 22    AK      5
# 23    NV      4
# 24    TN      4
# 25    OH      4
# 26    PA      4
# 27    IN      4
# 28    NH      3
# 29    ID      3
# 30    CT      3
# 31    LA      2
# 32    OK      2
# 33    SC      1
# 34    WY      1
# 35    NM      1
# 36    RI      1
# 37    ME      1
# 38    DC      1
# 39    MO      1
# 40    KS      1
# 41    KY      1

# %%
df.to_csv("2020_officials.csv", index=False)

# %%
df[df['Body Type'] == 'U.S. House'].reset_index()
# Out:
#     index    #                      Name State    Level   Body Type
# 0       2    3  Amata Coleman Radewag...    AS  Federal  U.S. House
# 1       9   10                  Ami Bera    CA  Federal  U.S. House
# 2      10   11                  Judy Chu    CA  Federal  U.S. House
# 3      11   12                    TJ Cox    CA  Federal  U.S. House
# 4      13   14                 Ro Khanna    CA  Federal  U.S. House
# 5      14   15                  Ted Lieu    CA  Federal  U.S. House
# 6      15   16              Doris Matsui    CA  Federal  U.S. House
# 7      16   17               Mark Takano    CA  Federal  U.S. House
# 8     297  288          Stephanie Murphy    FL  Federal  U.S. House
# 9     303  294       Michael San Nicolas    GU  Federal  U.S. House
# 10    305  296             Tulsi Gabbard    HI  Federal  U.S. House
# 11    386  374       Raja Krishnamoorthi    IL  Federal  U.S. House
# 12    429  416           Gregorio Sablan    MP  Federal  U.S. House
# 13    438  424                  Andy Kim    NJ  Federal  U.S. House
# 14    457  443                Grace Meng    NY  Federal  U.S. House
# 15    506  490               Bobby Scott    VA  Federal  U.S. House
# 16    511  495           Pramila Jayapal    WA  Federal  U.S. House

# %%
df_race = pd.read_csv("house_race.csv")

# %%
df_race.dtypes
# Out:
# Black               int64
# Asian               int64
# Hispanic            int64
# American_Indians    int64
# White               int64
# dtype: object

# %%
df_race = df_race.T

# %%
df_race
# Out:
#                    0   1
# Black             12  12
# Asian              3   6
# Hispanic           9  18
# American_Indians   1   1
# White             71  61

# %%
df_race.columns = ["house","population"]

# %%
df_race
# Out:
#                   house  population
# Black                12          12
# Asian                 3           6
# Hispanic              9          18
# American_Indians      1           1
# White                71          61

# %%
import seaborn as sns

# %%
df_race.plot(kind='bar',stacked=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0986cbe40d5e> in <module>
# ----> 1 df_race.plot(kind='bar',stacked=True)
#
# NameError: name 'df_race' is not defined

# %%
sns.relplot(data=df_race, x='house', y='population', hue=df_race.index, s=50)
plt.savefig("race_house.pdf")

# %% [markdown]
# #
